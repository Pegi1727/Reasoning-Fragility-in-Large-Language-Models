# %% [markdown]
# # Figure Generation: LLM Reasoning Fragility
#
# This notebook focuses exclusively on generating publication-quality figures for the paper **"The Fragility of Reasoning in Large Language Models"**.
#
# ### Workflow:
# 1. **Load Data**: Imports cleaned datasets from `data/`.
# 2. **Visualization Engine**: Contains the plotting functions for the Fragility Landscape and RPE decay curves.
# 3. **Export**: Saves output figures directly into the `figures/` directory.
#
# ---
# **Author**: [Pegah Merrikhi/Pegi1727]
# **Status**: Ready for Manuscript Production

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set style to publication standard
sns.set_theme(style="whitegrid", font="serif")

# Load datasets
df_full = pd.read_csv('../data/fragility_research_dataset.csv')
print("Datasets loaded successfully.")

# %% [markdown]
# ### Plotting Example:
# Uncomment the following code to generate a sample fragility landscape plot.

# %%
# Example: Plotting Figure 4.1
# plt.figure(figsize=(10, 6))
# sns.lineplot(data=df_full, x='complexity', y='error_rate', hue='model')
# plt.title('Fragility Landscape')
# plt.savefig('../figures/Figure_4_1_fragility_landscape.png', dpi=300)
# plt.show()
