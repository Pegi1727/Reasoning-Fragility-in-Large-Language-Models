# %% [markdown]
# # Statistical Analysis: LLM Reasoning Fragility
#
# This notebook contains the core statistical framework used in the paper **"The Fragility of Reasoning in Large Language Models"**.
#
# ### Objectives:
# 1. **Data Preprocessing**: Cleaning the raw inference results from the `data/` directory.
# 2. **Fragility Quantification**: Calculating the $k$ coefficient for various LLMs (GPT-4, PaLM, etc.).
# 3. **Bayesian Inference**: Estimating the posterior distributions for Reasoning Persistence Error (RPE).
# 4. **Visualization**: Generating Figure 4 and Figure 5 as presented in the manuscript.
#
# ---
# **Author**: [Your Name/Pegi1727]
# **Date**: June 2026
# **Status**: In Development / Peer-Review Ready

# %%
# Initial imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Environment Ready: Analysis environment initialized.")
